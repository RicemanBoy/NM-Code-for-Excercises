# %%
import numpy as np
from numpy.linalg import inv
from numpy.linalg import norm
import matplotlib.pyplot as plt

import sys
sys.path.insert(0,"C:/Users/Dustin/Desktop/Numerische Methoden/VS Code/NM-Code-for-Excercises")
import shortcuts as s

# %%
a = np.asfarray([-61.688, 72.5235, 72.822, -108.519, -5.12949, 39.9139, -7.07373, -3.91823, 1.0])
x = np.asfarray([0.9, -1.1, 1.4, 1.4, -2.0, -2.0, 2.2, 2.2])

# %%
def P(x,a):
    sum = 0
    for i in range(len(a)):
        sum += a[i]*(x**i)
    return sum

def P_k(x,a,k,x0):
    sum = 1
    for i in range(k):
        sum = sum*(x-x0[i])
    sum = P(x,a)/sum
    return sum

def Pstrich(x,a):
    sum = 0
    for i in range(len(a)):
        if i-1 < 0:
            sum += 0
        else:
            sum += a[i]*i*(x**(i-1))
    return sum

# %%
plt.figure(figsize=(20,6))
plt.plot(np.linspace(-2.55,3.3,100),P(np.linspace(-2.55,3.3,100),a))
plt.plot(np.linspace(-2.55,3.1,100),np.zeros(100))
plt.xticks(np.arange(-2.5, 3.5, 0.25))
plt.ylim(-0.01, 0.01)
# Out:
# (-0.01, 0.01)

# %%
xnew = np.zeros(len(a))

j = 0

while j < 10:

    for i in range(len(x)):
        x[i] = x[i] - (P(x[i],a))/(Pstrich(x[i],a)-P_k(x[i],a,i,x))
    
    xnew = x

    j += 1


print(xnew)
# Out:
# [ 1.00729288 -1.00040446  1.37706029  1.00611488 -1.73181243 -1.73181243
#   2.23412653  2.23412653]
